# %%
from plotnine import ggplot, aes, geom_point, scale_color_manual, labs, geom_smooth
import pandas as pd

# %%
df = pd.read_csv("../penglings.csv")

# %%
colors = ["#fba044","#9933cb","#479f9f"]

# %%
scatter_plot = ggplot(df, aes(x='flipper_length_mm', y='body_mass_g', color='species', size='bill_length_mm')) + \
    geom_point(alpha=0.7) + \
    scale_color_manual(values = colors) + \
    labs(x="Flipper Length (mm)", y="Body Mass (g)")+\
    geom_smooth(method="lm")
print(scatter_plot)
# Out:
# c:\Users\ics07\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
